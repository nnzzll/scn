# %%
import os
import json
import torch
import random
import argparse
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib
from network import SCN
from utils.filters import Gaussian
from utils.dataset import SpineDataset
from utils.util import generate_patches, Aggregator, generate_train_mask
from torch.utils.data import DataLoader
# Out:
# Using matplotlib backend: Qt5Agg

# %%
with open('data/info.json', "r") as f:
    INFO = json.load(f)

# %%
train_set = SpineDataset('E:\\Spine\\data\\2mm', INFO['train'], 'train', 25)
val_set = SpineDataset('E:\\Spine\\data\\2mm', INFO['val'], 'val', 25)
train_loader = DataLoader(train_set,1)
val_loader = DataLoader(val_set, 1)

# %%
ID,image,mask,landmark = next(iter(train_loader))

# %%
fig,ax = plt.subplots(1,2)
ax[0].imshow(image[0,0,:,:,48],'gray')
ax[1].imshow(mask[0,0,:,:,48])
